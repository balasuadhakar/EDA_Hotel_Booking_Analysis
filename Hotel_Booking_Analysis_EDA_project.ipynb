# %% [markdown]
# <a href="https://colab.research.google.com/github/balasuadhakar/EDA_Hotel_Booking_Analysis/blob/main/Hotel_Booking_Analysis_EDA_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis EDA Project

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Analysis of hotel bookings associated data is essential for all the hospitality commerce. The study gives the various aspects of booking behavior by the customers and provides the root map for improving the business.
# The provided data have been categorized in City hotel and Resort hotel for deep understanding about the features.
# The project deeds have been divided as following sections:
# 1.	Problem statement
# 2.	Business objectives
# 3.	Knowing the data
# 4.	Understanding the variables
# 5.	Data wrangling
# 6.	Data Visualization, Storytelling & Experimenting with charts
# 7.	Conclusion

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/balasuadhakar/EDA_Hotel_Booking_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The most of the hotel industries facing challenges for predicting the influential parameters for customer bookings, most demand periods , less booking periods and how to improve the bookings.
# This EDA project address the solution of following problems faced by the hotel industry
# 1.	Which are the months more demand for rooms and which are the month’s business need to be improved?
# 2.	Which meal types mostly preferred by the customer and which meal will be given less preference?
# 3.	What are the agents are active and inactive for booking the room?
# 4.	What are most preferred distribution channel by the customers?
# 5.	Which country customers are mostly visited and which country customers need to be attracted for more?
# 6.	What is the cancelation rate for both city hotel and resort hotel?
# 7.	What is the percentage of cancelation of repeated guests and new guests?
# 8.	Which year booking percentage will be more?
# 9.	Which months booking cancelations are more?
# 10.	How long most of the guests stay in city hotel and resort hotel?
# 11.	Which room types are mostly preferred by the customers?
# 12.	Which distribution channels did early bookings?
# 13.	What are the correlations between each variable?
# 14.	What is the relations between total people stayed and average daily rate value?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The main objectives of this EDA project are discover and analyze the given data for finding the various influencing factors of hotel bookings. The study results will be utilized for business improvement.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path= 'https://raw.githubusercontent.com/balasuadhakar/EDA_Hotel_Booking_Analysis/main/Hotel%20Bookings.csv'

# %%
df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_value_df=df.isnull().sum().sort_values(ascending=False)[ :6]
missing_value_df
# Out:
# company               112593
# agent                  16340
# country                  488
# children                   4
# reserved_room_type         0
# assigned_room_type         0
# dtype: int64

# %%
# Visualizing the missing values
missing_value_df.plot(kind='bar')
plt.yscale("log")
plt.xlabel('Columns')
plt.ylabel('Null values')
# Out:
# Text(0, 0.5, 'Null values')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset consists of a hotel industry based details. The dataset contains 119390 rows and 32 columns. The following columns have the null values such as children, country, agent and company. The duplicate values in the dataset have been counted as 31994. The aim is to explore and analyze the data. The results will be supported for the business improvement.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *   Hotel: H1= Resort Hotel, H2= City Hotel
# *   is_canceled : If the booking was canceled(1) or not(0)
# *   lead_time : Number of days that elapsed between the entering
# *   date of the booking into the PMS(Property Management System) and the arrival date
# *   arrival_date_year : Year of arrival date.
# *   arrival_date_month : Month of arrival date.
# *   arrival_date_week_number : Week number for arrival date.
# *   arrival_date_day_of_month: Which day of the months guest is arriving.
# *   stays_in_weekend_nights: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
# *   stays_in_week_nights: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
# *   adults : Number of adults.
# *   children : Number of children.
# *   babies : Number of babies.
# *   meal: kind of meal opted for.
# *   country : Country code.
# *   market_segment: Through which channel hotels were booked.
# *   distribution_channel : How the customer accessed the stay- Corporate Booking/Direct/TA.TO
# *   is_repeated_guest : The values indicating if the booking name was from a repeated guest (1) or not (0).
# *   previous_cancellations : Was there a cancellation before.
# *   previous_bookings_not_canceled : Count of previous bookings not cancelled.
# *   reserved_room_type : Code of room type reserved.
# *   assigned_room_type : Code for the type of room assigned to the booking.
# *   booking_changes : Count of changes made to booking.
# *   deposit_type : Deposit type.
# *   agent : If the booking happens through agents or not.
# *   company : If the booking happens through companies, the company ID that made the booking or responsible for paying the booking.
# *   days_in_waiting_list : Number of days the booking was on the waiting list before the confirmation to the customer.
# *   customer_type : Booking type like Transient – Transient-Party – Contract – Group.
# *   adr : Average Daily Rates that described via way of means of dividing the sum of all accommodations transactions using entire numbers of staying nights.
# *   required_car_parking_spaces : How many parking areas are necessary for the customers.
# *  total_of_special_requests : Total unique requests from consumers.
# *  reservation_status: The last status of reservation, assuming one of three categories: Canceled – booking was cancelled by the customer; Check-Out;No-Show.
# *  reservation_status_date: The last status date.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in list(df.columns):
  unique_values = df[i].nunique()
  print(f"Column name: {i} - unique values: {unique_values}")
# Out:
# Column name: hotel - unique values: 2
# Column name: is_canceled - unique values: 2
# Column name: lead_time - unique values: 479
# Column name: arrival_date_year - unique values: 3
# Column name: arrival_date_month - unique values: 12
# Column name: arrival_date_week_number - unique values: 53
# Column name: arrival_date_day_of_month - unique values: 31
# Column name: stays_in_weekend_nights - unique values: 17
# Column name: stays_in_week_nights - unique values: 35
# Column name: adults - unique values: 14
# Column name: children - unique values: 5
# Column name: babies - unique values: 5
# Column name: meal - unique values: 5
# Column name: country - unique values: 177
# Column name: market_segment - unique values: 8
# Column name: distribution_channel - unique values: 5
# Column name: is_repeated_guest - unique values: 2
# Column name: previous_cancellations - unique values: 15
# Column name: previous_bookings_not_canceled - unique values: 73
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Making copy of df to analyse
df_copy=df.copy()

# %%
# Checking the copy file
df_copy.head(1)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type  adr  \
# 0    NaN     NaN                    0     Transient  0.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
#
# [1 rows x 32 columns]

# %%
# Deleting the dublicate values in the dataset
df_copy.drop_duplicates(inplace=True)
df_copy.shape
# Out:
# (87396, 32)

# %%
# Finding the percentage of null values in each columns
100*(df_copy.isna().sum()/df_copy.shape[0]).sort_values(ascending=False)[ :6]
# Out:
# company               93.982562
# agent                 13.951439
# country                0.517186
# children               0.004577
# reserved_room_type     0.000000
# assigned_room_type     0.000000
# dtype: float64

# %%
# Droping the company column due to 94% of null values
df_copy.drop(columns=['company'],inplace=True)

# %%
# Changing null values in other three columns
df_copy.agent.fillna(0,inplace=True)
df_copy.country.fillna('Others',inplace=True)
df_copy.children.fillna(0,inplace=True)

# %%
# Again checking the null value counts in all column
df_copy.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
# Checking the data types of each columns
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %%
# From the above information data type in children and agent columns are not in integer
# Changing integer data type of two columns
df_copy.children = df_copy.children.astype(int)
df_copy.agent= df_copy.agent.astype(int)

# %%
# Checking the changes in data type of two columns
df_copy[['children','agent']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   children  87396 non-null  int64
#  1   agent     87396 non-null  int64
# dtypes: int64(2)
# memory usage: 2.0 MB

# %%
# Some rows adults,children and babies column are zero at same time it is not possible
# Removing rows that contains adults,children,babies are zero at same time
df_copy=df_copy[~((df_copy.adults==0) & (df_copy.children==0) & (df_copy.babies==0))]

# %%
# Checking the number of rows and columns in modified file
df_copy.shape
# Out:
# (87230, 31)

# %%
# Adding new column for total stay
df_copy['total_stay'] =df_copy.stays_in_week_nights+df_copy.stays_in_weekend_nights
df_copy.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
#
#    agent days_in_waiting_list customer_type  adr required_car_parking_spaces  \
# 0      0                    0     Transient  0.0                           0
# 1      0                    0     Transient  0.0                           0
#
#    total_of_special_requests  reservation_status  reservation_status_date  \
# ...

# %%
# Adding new column for total people stay
df_copy['total_people']=df_copy.adults+df_copy.children+df_copy.babies
df_copy[['adults','children','babies','total_people']].head()
# Out:
#    adults  children  babies  total_people
# 0       2         0       0             2
# 1       2         0       0             2
# 2       1         0       0             1
# 3       1         0       0             1
# 4       2         0       0             2

# %%
# Seperate dataset creation for Resort hotel and City hotel
df_resort_hotel=df_copy[df_copy.hotel=='Resort Hotel']
df_city_hotel = df_copy[df_copy.hotel=='City Hotel']

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *   The copy of data set was made for analysis.
# *   All the duplicated rows in the dataset were deleted.
# *   The company column was dropped due to 94% of null values.
# *   All the null values were replaced with other corresponding values
# *   The data types of children and agent columns were changed with integer.
# *   Two separate data frames such as city hotel and resort hotel have been created for analysis

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### **Chart - 1 Guests Arrival at each months**

# %%
# Chart - 1 visualization code
# Checking arrivals of guests at each months
months = ['August','July','May','October','April','June','September','March','February',"November",'December','January']
plt.figure(figsize=(14,7))
plt.pie(df_copy.arrival_date_month.value_counts(),
labels =months,
startangle = 90,
shadow = True,
explode =(0.1,0.1,0.1,0,0,0,0,0,0.1,0.1,0.1,0.1),
autopct ='%1.1f%%')
plt.title('Guest Arrival at each months')
# Out:
# Text(0.5, 1.0, 'Guest Arrival at each months')

# %%
# Guest arrivals at each  months in both Resort Hotel and City Hotel
sns.set(rc={'figure.figsize':(18,6)});
sns.countplot(data=df,x=df_copy.arrival_date_month,hue=df.hotel);
plt.title('Monthly Guest arrival pattern');
plt.xlabel('Months')
plt.ylabel('Number of guest arrival')
# Out:
# Text(0, 0.5, 'Number of guest arrival')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Based on the guest arrivals at each month we can identify which are the months more demand for rooms and which are the months business need to improve.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is identified from the chart that august,july,may months guests arrival are more and november,december,january months guest arrivals are very low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# During the months at low arrivals of guest some discount and offers can give to increase the arrivals.During high arrivals months price can be increased for profit.

# %% [markdown]
# #### **Chart - 2 Most prefered meal type by customer**

# %%
# Chart - 2 visualization code
# Finding most prefered meal
m=df_copy['meal'].value_counts()
m
# Out:
# BB           67907
# SC            9391
# HB            9080
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %%
# Visualization of meal prefered by customers
plt.figure(figsize=(10,5))
plt.bar(m.index, m.values, color='pink')
plt.yscale("log")
plt.title("Meal Categories and their count")
plt.xlabel('meal')
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
# Meal Preference in each city hotel and resort hotel
m_hotel=df_copy[['meal','hotel']].value_counts().unstack()
m_hotel
# Out:
# hotel      City Hotel  Resort Hotel
# meal
# BB            41160.0       26747.0
# FB               11.0         349.0
# HB             2786.0        6294.0
# SC             9317.0          74.0
# Undefined         NaN         492.0

# %%
# Visualization of meal preference in each hotels
plt.figure(figsize=(12,6))
ax=sns.countplot (data= df_copy,x= 'meal',hue= 'hotel')
plt.xticks(size=20)
plt.yticks(size=20)
plt.xlabel('Types of Meal',size=15)
plt.ylabel('count',size=15)
plt.title("Preferred Meal Categories for both hotels")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Categories for both hotels')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We can identify which meal types mostly prefered by the customer and which meal will given less prefeence.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is obserbed that BB type meal mostly prefered and FB type meal very few people only prefered.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Most liked meal type was identified.They can prepare more quantity of meals.Less prefered meal can be prepared in less quantity.

# %% [markdown]
# #### **Chart - 3 Identifying the active and inactive agent**

# %%
# Chart - 3 visualization code
# Visual comparison of booking by various agent 
df_copy.loc[df_copy['agent']!=0,'agent'].value_counts().plot(kind='pie',title='Comparison of Bookings done by agents')
plt.figure(figsize = (20,5))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We can identify the active agent and inactive agent for booking the rooms.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is gathered that the agents 9, 240 are more active and agents 14,7,250,241 are moderate active.The remaining agents are very low active

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# More active agents can be motivated by some complements and it will lead the improvement of booking in less active agents also

# %% [markdown]
# #### **Chart - 4 Identifying most common distribution channel for booking**

# %%
# Chart - 4 visualization code
# Visualization of most common distribution channel for booking
group_by_dc = df_copy.groupby('distribution_channel')
plt.figure(figsize=(8,4))
d1 = pd.DataFrame(round((group_by_dc.size()/df.shape[0])*100,2)).reset_index().rename(columns = {0: 'Booking_%'})
plt.figure(figsize = (8,8))
data = d1['Booking_%']
labels = d1['distribution_channel']
plt.pie(x=data, autopct="%.2f%%", explode=[0.05]*5, labels=labels, pctdistance=0.5)
plt.title("Booking percentage by various distribution channels", fontsize=14);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We can identify how customer accessed the stay- Corporate Booking/Direct/TA.TO

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most of the customer accessed through TA.TO and least customer acessed through corporate booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Corporate booking are less.It can be improved by various strategical plans.

# %% [markdown]
# #### **Chart - 5  Countrywise Customers arrivals**

# %%
# Chart - 5 visualization code
# Finding number of customers in countrywise

customer_country = df_copy[df_copy['is_canceled'] == 0]['country'].value_counts().reset_index()
customer_country.columns = ['Country', 'No of guests']
customer_country
# Out:
#     Country  No of guests
# 0       PRT         17573
# 1       GBR          8440
# 2       FRA          7091
# 3       ESP          5382
# 4       DEU          4332
# ..      ...           ...
# 161     ZMB             1
# 162     SYC             1
# 163     MDG             1
# 164     SMR             1
# 165     FRO             1
#
# [166 rows x 2 columns]

# %%
# Visualization of top 10 countries of origin of the guests
x=df_copy.country.value_counts()
z=sns.countplot(x=df_copy[df_copy['is_canceled'] == 0]['country'], data=df_copy,order=pd.value_counts(df_copy['country']).iloc[:10].index,palette= 'colorblind')
plt.title('Top 10 Countries of Origin of the Guests', weight='bold')
plt.xlabel('Country')
plt.ylabel('Reservation Count')
for p in z.patches:
    z.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify the country of origin of most visited customer and to identify less visiting country peoples

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart it is idendified that most guests arrived from PRT country and top ten countries of most guests arrivals have been identified.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Based on top ten country people hotels can attract  the people by giving their traditional foods and they can arrange interiors in their country styles.New stragy can be followed to attract the customer from less visiting countries.

# %% [markdown]
# #### **Chart - 6 Percentage of cancelled bookings in City hotel and Resort hotel**

# %%
# Chart - 6 visualization code
# Finding percentage of cancelled booking of City hotel and Resort hotel

df_copy["Canceled_bookings"]=df_copy.is_canceled
booking_canc=df_copy.groupby('hotel')['Canceled_bookings'].describe()
a=booking_canc.index
b=booking_canc['mean']*100
sns.barplot(data=df,x=a,y=b);
plt.title('Total Cancelled Bookings');
plt.ylabel('Cancellations(%)');
plt.xlabel('Hotel Type');

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify the cancelation rate on both the hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has the more percentage cancelation compared to resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the total cancelation city hotel has the more percentage of cancelation of booking.The reasons for cancelation can be analysed and it will lead the reduction of cancelation.

# %% [markdown]
# #### Chart - 7 Finding percentage cancelations of repeated guests and new guests

# %%
# Chart - 7 visualization code
# Finding Number of cancelation

df_copy['is_canceled'].value_counts()
# Out:
# 0    63221
# 1    24009
# Name: is_canceled, dtype: int64

# %%
# Finding cancelation by repeated guests
df_copy[['is_canceled','is_repeated_guest']].value_counts().unstack()
# Out:
# is_repeated_guest      0     1
# is_canceled
# 0                  60117  3104
# 1                  23749   260

# %%
# Creating function for showing the percentage in countplot
def countplotpercent(df_copy,xvariable,ax):

    # 1. how many X categories
    ##   check for NaN and remove
    numX=len([x for x in df[xvariable].unique() if x==x])

    # 2. The bars are created in hue order, organize them
    bars = ax.patches
    ## 2a. For each X variable
    for ind in range(numX):
        ## 2b. Get every hue bar
        ##     ex. 8 X categories, 4 hues =>
        ##    [0, 8, 16, 24] are hue bars for 1st X category
        hueBars=bars[ind:][::numX]
        ## 2c. Get the total height (for percentages)
        total = sum([x.get_height() for x in hueBars])

        # 3. Print the percentage on the bars
        for bar in hueBars:
            ax.text(bar.get_x() + bar.get_width()/2.,
                    bar.get_height(),
                    f'{bar.get_height()/total:.0%}',
                    ha="center",va="bottom")

# %%
# Visulalization of repeated guest cancelation
plt.figure(figsize=(10,5))
ax=sns.countplot (x= 'is_canceled', data= df_copy, hue= 'is_repeated_guest')
plt.xticks(size=15)
plt.xlabel('Not Canceled(0) or Canceled(1)',size=15)
plt.yticks(size=15)
plt.ylabel('count',size=15)
plt.title("Repeated guest relation with cancelation")
countplotpercent(df_copy,'is_canceled',ax)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the percentage of cancelation of repeated guest and new guest

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is found that 99% cancelations were done by new guests and 1% cancelations were done by repeated guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The cancelations from new guests are 99%. the reasons for cancelations can be analysed and it can be reduced.

# %% [markdown]
# #### **Chart - 8 Percentage of bookings in each year**

# %%
# Chart - 8 visualization code
# Finding number of bookings on each year
df_copy['arrival_date_year'].value_counts().sort_index()
# Out:
# 2015    13284
# 2016    42313
# 2017    31633
# Name: arrival_date_year, dtype: int64

# %%
# Finding number of bookings in each year for city hotel and resort hotel
df_copy[['arrival_date_year','hotel']].value_counts().unstack()
# Out:
# hotel              City Hotel  Resort Hotel
# arrival_date_year
# 2015                     6526          6758
# 2016                    26684         15629
# 2017                    20064         11569

# %%
# Visulization of booking percentage on each year for both type hotels
plt.figure(figsize=(10,5))
ax=sns.countplot (x= 'arrival_date_year', data= df_copy, hue= 'hotel')
plt.xticks(size=15)
plt.xlabel('Year Of Booking',size=15)
plt.yticks(size=15)
plt.ylabel('count',size=15)
plt.title("Hotel Booking Distribution")
countplotpercent(df_copy,"arrival_date_year",ax)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the percentage of booking on every year for both type of hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the year 2016 and 2017 percentage of booking of city hotel is 63% and resort hotel is 37%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In the year of 2016 and 2017 resort hotel bookings are less percentage.It can be improved by marketing strategies.

# %% [markdown]
# #### **Chart - 9 Percentage of cancelations on monthwise**

# %%
# Chart - 9 visualization code
# Finding monthwise bookings and cancelations
df_copy[['arrival_date_month','is_canceled']].value_counts().unstack()
# Out:
# is_canceled            0     1
# arrival_date_month
# April               5494  2406
# August              7620  3622
# December            3735  1377
# February            4671  1412
# January             3648  1037
# July                6847  3196
# June                5403  2353
# March               5660  1829
# May                 5902  2442
# November            3921  1052
# October             5279  1642
# September           5041  1641

# %%
# Finding monthwise cancelation
plt.figure(figsize=(20,5))
ax=sns.countplot (x= 'arrival_date_month', data= df_copy, hue= 'is_canceled')
plt.xticks(size=15)
plt.xlabel('Month Of Booking',size=15)
plt.yticks(size=15)
plt.ylabel('count',size=15)
plt.title("Monthly Booking cancelations")
countplotpercent(df_copy,'arrival_date_month',ax)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the cancelation percentage of each months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The months of april,may,june,july, august the cancelation percentage is more.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The months of april,may,june,july,august the cancelations are more.It can be rectified by some remedial activities.

# %% [markdown]
# #### **Chart - 10 Finding how long people stay in hotel**

# %%
# Chart - 10 visualization code
# Finding how long people stay in resort hotel 
df_resort_hotel['total_stay'].value_counts()
# Out:
# 1     6899
# 7     5675
# 2     4921
# 3     4285
# 4     3955
# 5     2561
# 6     1625
# 10     884
# 14     771
# 8      700
# 9      581
# 0      360
# 11     291
# 12     138
# 13      93
# 21      45
# 15      32
# 28      31
# 16      18
# 18      18
# 17      12
# 25      12
# 19      10
# 22       6
# 35       5
# 30       5
# 42       4
# 26       3
# 23       3
# 29       3
# 56       2
# 60       1
# 45       1
# 69       1
# 46       1
# 27       1
# 33       1
# 20       1
# 38       1
# Name: total_stay, dtype: int64

# %%
# Visualization of percentage of duration of stay in resort hotel
plt.figure(figsize=(24,5))
total = float(len(df_resort_hotel))
ax = sns.countplot(x='total_stay', data=df_resort_hotel)
plt.title('Distribution Of Stay Duration For Resort Hotels', fontsize=20)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.show()

# %%
# Finding howlong people stay in city hotel 
df_city_hotel['total_stay'].value_counts()
# Out:
# 3     13542
# 2     10813
# 1     10270
# 4      9610
# 5      4168
# 7      1845
# 6      1638
# 8       362
# 0       231
# 9       198
# 10      188
# 14       88
# 11       76
# 12       58
# 13       40
# 15       37
# 16       15
# 20       13
# 19       12
# 29       10
# 21       10
# 17        8
# 30        8
# 22        6
# 24        6
# 18        6
# 27        3
# 26        3
# 28        3
# 23        2
# 25        2
# 48        1
# 33        1
# 34        1
# Name: total_stay, dtype: int64

# %%
# Visualization of percentage of duration of stay in city hotel
plt.figure(figsize=(24,5))
total = float(len(df_resort_hotel))
ax = sns.countplot(x='total_stay', data=df_city_hotel)
plt.title('Distribution Of Stay Duration For City Hotels', fontsize=20)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the percentage duration of stay in both hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In resort hotel 20% stays in 1 night and in city hotel 40% of stays in 3 nights.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In resort hotel duration of stays are less.Most of stays 1 night stay only.Duration of stay need to be improved in resort hotels.

# %% [markdown]
# #### **Chart-11 Finding mostly prefered room type by the customer**

# %%
# Chart - 11 visualization code
# Finding mostly prefered room type by the customer in resort hotel
plt.figure(figsize=(24,5))
total = float(len(df_resort_hotel))
ax = sns.countplot(x='reserved_room_type', data=df_resort_hotel)
plt.title('Mostly prefered room type by the customer in resort hotel', fontsize=20)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.show()

# %%
# Finding mostly prefered room type by the customer in city hotel
plt.figure(figsize=(24,5))
total = float(len(df_resort_hotel))
ax = sns.countplot(x='reserved_room_type', data=df_city_hotel)
plt.title('Mostly prefered room type by the customer in city hotel', fontsize=20)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the customer prefered room types in both hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In resort hotel 55% booking on room type A and in city hotel 111% of prefereance on A type room

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Most of the customer like to stay in A type room and next D type room.Other types of rooms have the less preferences.

# %% [markdown]
# #### **Chart - 12 Finding mostly used distribution channel for early booking of hotels**

# %%
# Chart - 12 visualization code
# finding mostly used distribution channel for early booking of hotels
group_by_dc = df_copy.groupby('distribution_channel')
d2 = pd.DataFrame(round(group_by_dc['lead_time'].median(),2)).reset_index().rename(columns = {'lead_time': 'median_lead_time'})
plt.figure(figsize = (7,5))
sns.barplot(x = d2['distribution_channel'], y = d2['median_lead_time'])
plt.title("mostly used for the early booking of hotels")
plt.ylabel('Median leadtime');
plt.xlabel('Distribution Channel');
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find mostly used distribution channel for early bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the early bookings have done by TA/TO distribution channel and less early bookings are done by corporate channel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Most early bookings done by TA/TO channel.Corporate channel have the less early bookings and it need to be improved.

# %% [markdown]
# #### **Chart - 13 Finding which channel has longer average waiting time**

# %%
# Chart - 13 visualization code
#Finding average waiting time for each distribution_channel 
d4 = pd.DataFrame(round((group_by_dc['days_in_waiting_list']).mean(),2)).reset_index().rename(columns = {'days_in_waiting_list': 'avg_waiting_time'})
plt.figure(figsize = (7,5))
sns.barplot(x = d4['distribution_channel'], y = d4['avg_waiting_time'])
plt.title("distribution_channel and their avg_waiting_time")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the average waiting time for each channels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TA/TO channel average wating time is more than other channel and corporate channel has the least average waiting time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# TA/TO channel waiting time can be reduced by appropriate methods

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(18,10))
plt.title('Correlation of the columns')
sns.heatmap(df_copy.corr(),vmin=-1,annot=True,cmap='coolwarm')
# Out:
# <Axes: title={'center': 'Correlation of the columns'}>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the correlation coefficient between the each variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.	is_repeated guest and previous bookings not canceled has strong correlation. It shows that the repeated guests are not more likely to cancel their bookings.
# 2.	There is a positive correlation between lead time and total stay
# 3.	stays_in_week_nights has a high correlation  with stays_in_weekend_nights.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Based on the correlation relations of variables root map for business improvement will be identified

# %% [markdown]
# #### **Chart - 15 - Pair Plot Finding the relation between total people stayed and average daily rate value**

# %%
# Pair Plot visualization code
# Droping adr value if more than 5000 for better visibility of graph
df_copy.drop(df_copy[df_copy['adr'] > 5000].index, inplace = True)
# Ploting box chart total people Vs adr value
plt.figure(figsize=(20,10))
df2=df_copy[df_copy['total_people'] < 6]

sns.boxplot(x=df2['total_people'],y=df2['adr'])

# set lables
plt.title('ADR v/s Total Number of people')
# Out:
# Text(0.5, 1.0, 'ADR v/s Total Number of people')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the relation between total people stayed and adr value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The adr value increases when the number of people increase.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The pattern of adr value has been identified and it will be used for business growth

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The following suggetions are provided to the client to achieve the business objective.
# 1.	is_repeated guest and previous bookings not canceled has strong correlation. It shows that the repeated guests are not more likely to cancel their bookings.
# 2.	There is a positive correlation between lead time and total stay
# 3.	stays_in_week_nights has a high correlation  with stays_in_weekend_nights.
# 4.	During the months at low arrivals of guest some discount and offers can give to increase the arrivals.During high arrivals months price can be increased for profit.
# 5.	Most liked meal type was identified.They can prepare more quantity of meals.Less prefered meal can be prepared in less quantity.
# 6.	More active agents can be motivated by some complements and it will lead the improvement of booking in less active agents also
# 7.	Corporate booking are less.It can be improved by various strategical plans.
# 8.	Based on top ten country people hotels can attract the people by giving their traditional foods and they can arrange interiors in their country styles.New stragy can be followed to attract the customer from less visiting countries.
# 9.	From the total cancelation city hotel has the more percentage of cancelation of booking.The reasons for cancelation can be analysed and it will lead the reduction of cancelation.
# 10.	The cancelations from new guests are 99%. the reasons for cancelations can be analysed and it can be reduced.
# 11.	In the year of 2016 and 2017 resort hotel bookings are less percentage.It can be improved by marketing strategies.
# 12.	The months of april,may,june,july,august the cancelations are more.It can be rectified by some remedial activities.
# 13.	In resort hotel duration of stays are less.Most of stays 1 night stay only.Duration of stay need to be improved in resort hotels.
# 14.	Most of the customer like to stay in A type room and next D type room.Other types of rooms have the less preferences.
# 15.	Most early bookings done by TA/TO channel.Corporate channel have the less early bookings and it need to be improved.
# 16.	TA/TO channel waiting time can be reduced by appropriate methods
# 17.	Based on the correlation relations of variables root map for business improvement will be identified
# 18.	The pattern of adr value has been identified and it will be used for business growth

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project offers the most useful findings to improve the hotel industry business.
# The following conclusions are summarized from this study:
# 1.	It is identified that the guest arrivals are more on august, July, may months and very low on November, December, January months.
# 2.	The BB type meal mostly preferred by customers and FB type meal very few people only preferred.
# 3.	The agents 9, 240 are more active and the agents 14, 7,250,241 are moderate active. The remaining agents are very low active for booking.
# 4.	The most of the customer accessed booking through TA.TO and least customer accessed through corporate booking.
# 5.	Most guests arrived from PRT country and following that GEBR, FRA, ESP and DEU are top five countries of most guests arrivals.
# 6.	City hotel has the more cancelations compared to resort hotel.
# 7.	The 99% cancelations were done by new guests and 1% cancelations were done by repeated guests.
# 8.	In the year 2016 and 2017 percentage of booking of city hotel is 63% and resort hotel is 37%.
# 9.	The months of April, may, June, July, august the cancelation percentage is more.
# 10.	In resort hotel 20% stays in 1 night and in city hotel 40% of stays in 3 nights.
# 11.	In resort hotel 55% booking on room type A and in city hotel 111% of preferences on A type room
# 12.	Most of the early bookings have done by TA/TO distribution channel and less early bookings are done by corporate channel.
# 13.	TA/TO channel average waiting time is more than other channel and corporate channel has the least average waiting time.
# 14.	Repeated guest and previous bookings not canceled has the strong correlation. It shows that the repeated guests are not more likely to cancel their bookings.
# 15.	The average daily rate value increases when the number of people increases.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
